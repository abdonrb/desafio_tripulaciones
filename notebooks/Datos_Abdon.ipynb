# %%
import pandas as pd
import requests
import polars as pl

# %%
url = "https://datos.madrid.es/egob/catalogo/206717-0-agenda-eventos-bibliotecas.json"

response = requests.get(url)
data = response.json()

# %%
df = pd.DataFrame(data['@graph'])

# %%
df
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/eve...
# 1    https://datos.madrid.es/egob/catalogo/tipo/eve...
# 2    https://datos.madrid.es/egob/catalogo/tipo/eve...
# 3    https://datos.madrid.es/egob/catalogo/tipo/eve...
# 4    https://datos.madrid.es/egob/catalogo/tipo/eve...
# ..                                                 ...
# 254  https://datos.madrid.es/egob/catalogo/tipo/eve...
# 255  https://datos.madrid.es/egob/catalogo/tipo/eve...
# 256  https://datos.madrid.es/egob/catalogo/tipo/eve...
# 257  https://datos.madrid.es/egob/catalogo/tipo/eve...
# 258  https://datos.madrid.es/egob/catalogo/tipo/eve...
#
#                                                  @type        id  \
# 0    https://datos.madrid.es/egob/kos/actividades/C...  12750408
# 1    https://datos.madrid.es/egob/kos/actividades/C...  12753990
# 2    https://datos.madrid.es/egob/kos/actividades/C...  12754420
# ...

# %%
#df2 = pd.read_csv(r'..\data\raw\areas_infantiles202504.csv',delimiter=';')
df2 = pd.read_csv(r'../data/raw/areas_infantiles202504.csv',delimiter=';')

# %%
df2
# Out:
#            ID DESC_CLASIFICACION  COD_BARRIO       BARRIO  COD_DISTRITO  \
# 0       16658      Área Infantil          15  UNIVERSIDAD             1
# 1       16660      Área Infantil          15  UNIVERSIDAD             1
# 2       16664      Área Infantil          11      PALACIO             1
# 3       16666      Área Infantil          14     JUSTICIA             1
# 4       16668      Área Infantil          11      PALACIO             1
# ...       ...                ...         ...          ...           ...
# 2123  8800261      Área Infantil         215   CORRALEJOS            21
# 2124  8941726      Área Infantil         125     MOSCARDO            12
# 2125  8941727      Área Infantil         124  ALMENDRALES            12
# 2126  9348753      Área Infantil         205        ROSAS            20
# 2127  9424149      Área Infantil          22      ACACIAS             2
#
#                    DISTRITO     ESTADO  COORD_GIS_X  COORD_GIS_Y  \
# ...

# %%
# df3 = pd.read_csv(r'..\data\raw\juegos_areas_infantiles202504.csv',delimiter=';')
df3 = pd.read_csv(r'../data/raw/juegos_areas_infantiles202504.csv',delimiter=';')

# %%
df3
# Out:
#            ID                 DESC_CLASIFICACION  COD_BARRIO  \
# 0     9959188  Varios Juegos en Áreas Infantiles         181
# 1     9945493          Escalada en Área Infantil          11
# 2     9945489          Balancín en Área Infantil          11
# 3     9929591          Carrusel en Área Infantil          83
# 4     9928418          Columpio en Área Infantil         111
# ...       ...                                ...         ...
# 9904    21579          Columpio en Área Infantil         166
# 9905    21586          Columpio en Área Infantil         174
# 9906    34227        Multijuego en Área Infantil         213
# 9907    34776          Balancín en Área Infantil          23
# 9908    34807          Balancín en Área Infantil          52
#
#                            BARRIO  COD_DISTRITO             DISTRITO  \
# 0     CASCO HISTORICO DE VALLECAS            18    VILLA DE VALLECAS
# 1                         PALACIO             1               CENTRO
# ...
